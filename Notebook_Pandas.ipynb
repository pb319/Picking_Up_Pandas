# %%
import pandas as pd

# %% [markdown]
# ## Creating, Reading and Writing

# %% [markdown]
# ### Basic Definition and reading

# %%
df = pd.DataFrame({"Rana":[93, 85], "Pranay":[97,87]}, index=["Maths", "Stats"])
print(df)
# Out:
#        Rana  Pranay
# Maths    93      97
# Stats    85      87

# %% [markdown]
# **2. Creating a Series**

# %%
s1 = pd.Series([87,97], index=["Maths", "Stats"], name="Maths")
print(s1)
# Out:
# Maths    87
# Stats    97
# Name: Maths, dtype: int64

# %%
ed = pd.read_csv("constituency_wise_results_2019.csv", index_col=0)
ed.shape
# Out:
# (8597, 11)

# %% [markdown]
# ## Indexing, Selecting and Assigning

# %% [markdown]
# ### Accessing Attributes

# %% [markdown]
# #### Native Paradigm

# %%
ed.sex
# Out:
# state
# Andhra Pradesh      MALE
# Andhra Pradesh      MALE
# Andhra Pradesh    FEMALE
# Andhra Pradesh    FEMALE
# Andhra Pradesh      MALE
#                    ...
# Puducherry        FEMALE
# Puducherry          MALE
# Puducherry          MALE
# Puducherry          MALE
# Puducherry           NaN
# Name: sex, Length: 8597, dtype: object

# %% [markdown]
# **4. Using [] operator**

# %%
ed[["pc_name","sex"]]
# Out:
#                    pc_name     sex
# state
# Andhra Pradesh      Aruku     MALE
# Andhra Pradesh      Aruku     MALE
# Andhra Pradesh      Aruku   FEMALE
# Andhra Pradesh      Aruku   FEMALE
# Andhra Pradesh      Aruku     MALE
# ...                    ...     ...
# Puducherry      Puducherry  FEMALE
# Puducherry      Puducherry    MALE
# Puducherry      Puducherry    MALE
# Puducherry      Puducherry    MALE
# Puducherry      Puducherry     NaN
#
# [8597 rows x 2 columns]

# %% [markdown]
# #### "iloc" operator -- row call(treats dataframe like a big matrix)

# %%
ed.iloc[5]
# Out:
# pc_name                          Aruku
# candidate         SWAMULA. SUBRAHMANYAM
# sex                                MALE
# age                                50.0
# category                             ST
# party                             JAJGP
# party_symbol                       Mike
# general_votes                      4705
# postal_votes                          5
# total_votes                        4710
# total_electors                  1451418
# Name: Andhra Pradesh, dtype: object

# %%
ed.iloc[:4,[1,3]]
# Out:
#                                                         candidate   age
# state
# Andhra Pradesh                                KISHORE CHANDRA DEO  72.0
# Andhra Pradesh  Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...  54.0
# Andhra Pradesh                                   GODDETI. MADHAVI  26.0
# Andhra Pradesh                             SHRUTI DEVI VYRICHERLA  46.0

# %%
ed.iloc[:4,1:3]
# Out:
#                                                         candidate     sex
# state
# Andhra Pradesh                                KISHORE CHANDRA DEO    MALE
# Andhra Pradesh  Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...    MALE
# Andhra Pradesh                                   GODDETI. MADHAVI  FEMALE
# Andhra Pradesh                             SHRUTI DEVI VYRICHERLA  FEMALE

# %% [markdown]
# **6. Specific column using "iloc"**

# %%
ed.iloc[:,1]
# Out:
# state
# Andhra Pradesh                                  KISHORE CHANDRA DEO
# Andhra Pradesh    Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...
# Andhra Pradesh                                     GODDETI. MADHAVI
# Andhra Pradesh                               SHRUTI DEVI VYRICHERLA
# Andhra Pradesh                                  GANGULAIAH VAMPURU.
#                                         ...
# Puducherry                               TIRAVITAMANKAI@LOURDHUMARY
# Puducherry                                              IMS. BALAJI
# Puducherry                                                 RAMESH.D
# Puducherry                                            V. RAMAMURTHI
# Puducherry                                                     NOTA
# Name: candidate, Length: 8597, dtype: object

# %%
ed.iloc[-5:,:2]
# Out:
#                pc_name                   candidate
# state
# Puducherry  Puducherry  TIRAVITAMANKAI@LOURDHUMARY
# Puducherry  Puducherry                 IMS. BALAJI
# Puducherry  Puducherry                    RAMESH.D
# Puducherry  Puducherry               V. RAMAMURTHI
# Puducherry  Puducherry                        NOTA

# %% [markdown]
# #### Label Based using "loc" (Considers indices)

# %%
ed.loc[["West Bengal","Puducherry"],["sex","total_votes", "total_electors"] ]
# Out:
#                 sex  total_votes  total_electors
# state
# West Bengal    MALE       677363         1814200
# West Bengal    MALE        46810         1814200
# West Bengal    MALE       731594         1814200
# West Bengal  FEMALE        28215         1814200
# West Bengal    MALE         2078         1814200
# ...             ...          ...             ...
# Puducherry   FEMALE          870          973410
# Puducherry     MALE         2546          973410
# Puducherry     MALE         1653          973410
# Puducherry     MALE          642          973410
# Puducherry      NaN        12199          973410
#
# [527 rows x 3 columns]

# %%
ed.loc["West Bengal" :"Puducherry",["sex","total_votes", "total_electors"] ]
# Out:
#                 sex  total_votes  total_electors
# state
# West Bengal    MALE       677363         1814200
# West Bengal    MALE        46810         1814200
# West Bengal    MALE       731594         1814200
# West Bengal  FEMALE        28215         1814200
# West Bengal    MALE         2078         1814200
# ...             ...          ...             ...
# Puducherry   FEMALE          870          973410
# Puducherry     MALE         2546          973410
# Puducherry     MALE         1653          973410
# Puducherry     MALE          642          973410
# Puducherry      NaN        12199          973410
#
# [1712 rows x 3 columns]

# %% [markdown]
# **++ Contrast iloc/loc -->** iloc uses the Python stdlib indexing scheme, where the first element of the range is included and the last one excluded. So 0:10 will select entries 0,...,9. loc, meanwhile, indexes inclusively. So 0:10 will select entries 0,...,10.

# %% [markdown]
# ###  Manipulating the index

# %%
ed.set_index("candidate")
# Out:
#                                                        pc_name     sex   age  \
# candidate
# KISHORE CHANDRA DEO                                     Aruku     MALE  72.0
# Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYAN...      Aruku     MALE  54.0
# GODDETI. MADHAVI                                        Aruku   FEMALE  26.0
# SHRUTI DEVI VYRICHERLA                                  Aruku   FEMALE  46.0
# GANGULAIAH VAMPURU.                                     Aruku     MALE  49.0
# ...                                                        ...     ...   ...
# TIRAVITAMANKAI@LOURDHUMARY                          Puducherry  FEMALE  57.0
# IMS. BALAJI                                         Puducherry    MALE  32.0
# RAMESH.D                                            Puducherry    MALE  49.0
# V. RAMAMURTHI                                       Puducherry    MALE  74.0
# NOTA                                                Puducherry     NaN   NaN
#
#                                                    category  party  \
# candidate
# KISHORE CHANDRA DEO                                      ST    TDP
# Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYAN...       ST    BJP
# GODDETI. MADHAVI                                         ST  YSRCP
# SHRUTI DEVI VYRICHERLA                                   ST    INC
# GANGULAIAH VAMPURU.                                      ST    JnP
# ...                                                     ...    ...
# TIRAVITAMANKAI@LOURDHUMARY                          GENERAL    IND
# IMS. BALAJI                                         GENERAL    IND
# RAMESH.D                                                 SC    IND
# V. RAMAMURTHI                                       GENERAL    IND
# NOTA                                                    NaN   NOTA
#
#                                                      party_symbol  \
# candidate
# KISHORE CHANDRA DEO                                       Bicycle
# Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYAN...          Lotus
# GODDETI. MADHAVI                                      Ceiling Fan
# SHRUTI DEVI VYRICHERLA                                       Hand
# GANGULAIAH VAMPURU.                                 Glass Tumbler
# ...                                                           ...
# TIRAVITAMANKAI@LOURDHUMARY                                  Slate
# IMS. BALAJI                                                   Bat
# RAMESH.D                                                     Mike
# V. RAMAMURTHI                                             Whistle
# NOTA                                                          NaN
#
#                                                     general_votes  \
# candidate
# KISHORE CHANDRA DEO                                        336163
# Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYAN...          17578
# GODDETI. MADHAVI                                           557561
# SHRUTI DEVI VYRICHERLA                                      17656
# GANGULAIAH VAMPURU.                                         42245
# ...                                                           ...
# TIRAVITAMANKAI@LOURDHUMARY                                    870
# IMS. BALAJI                                                  2546
# RAMESH.D                                                     1653
# V. RAMAMURTHI                                                 641
# NOTA                                                        12192
#
#                                                     postal_votes  total_votes  \
# candidate
# KISHORE CHANDRA DEO                                         1938       338101
# Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYAN...           289        17867
# GODDETI. MADHAVI                                            4629       562190
# SHRUTI DEVI VYRICHERLA                                        74        17730
# GANGULAIAH VAMPURU.                                          549        42794
# ...                                                          ...          ...
# TIRAVITAMANKAI@LOURDHUMARY                                     0          870
# IMS. BALAJI                                                    0         2546
# RAMESH.D                                                       0         1653
# V. RAMAMURTHI                                                  1          642
# NOTA                                                           7        12199
#
#                                                     total_electors
# candidate
# KISHORE CHANDRA DEO                                        1451418
# Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYAN...         1451418
# GODDETI. MADHAVI                                           1451418
# SHRUTI DEVI VYRICHERLA                                     1451418
# GANGULAIAH VAMPURU.                                        1451418
# ...                                                            ...
# TIRAVITAMANKAI@LOURDHUMARY                                  973410
# IMS. BALAJI                                                 973410
# RAMESH.D                                                    973410
# V. RAMAMURTHI                                               973410
# NOTA                                                        973410
#
# [8597 rows x 10 columns]

# %% [markdown]
# ### Conditional selection

# %%
ed[((ed.party_symbol=="Lotus") |(ed.party_symbol=="Flowers and Grass")) & (ed.total_electors>= 100000)& (ed.pc_name == "Barasat")].loc["West Bengal"]

# %%
ed.loc[((ed.party_symbol=="Lotus") |(ed.party_symbol=="Flowers and Grass")) & (ed.total_electors>= 100000)& (ed.pc_name == "Barasat")]

# %%
ed[(ed.total_electors >= 315031)& (ed.pc_name == "Barasat")].loc["West Bengal"]

# %%
ed.total_electors.max()

# %%
ed.loc[(ed.total_electors > 150000)&(ed.party.isin(["BJP","INC"]))]

# %%
ed.describe()

# %%
ed.head(2)

# %%
ed.loc[(ed.party.isin(["BJP","INC"])) & (ed.pc_name == "Barasat")]

# %%
ed.loc[ed.party_symbol.isnull()].shape #Total NOTA Votes
# Out:
# (543, 11)

# %%
ed.loc[ed.party_symbol.notnull()].shape
# Out:
# (8054, 11)

# %% [markdown]
# ### Assigning Data

# %%
ed["Critic"] ="Everyone"

# %%
ed.head(5)

# %% [markdown]
# ## Summary Functions and Maps

# %% [markdown]
# ### Summary Functions

# %%
ed.describe()

# %%
ed.total_electors.describe()

# %%
ed.candidate.describe()

# %%
ed.total_votes.mean()
# Out:
# 71440.3655926486

# %%
ed.total_votes.max()
# Out:
# 1068569

# %%
ed.party.unique()
# Out:
# array(['TDP', 'BJP', 'YSRCP', 'INC', 'JnP', 'JAJGP', 'IND', 'NOTA',
#        'PPOI', 'SAPRP'], dtype=object)

# %%
ed.party.value_counts()
# Out:
# party
# IND       3461
# NOTA       543
# BJP        436
# INC        421
# BSP        383
#           ...
# ABEP         1
# HiPPa        1
# BEPP         1
# MAHKRS       1
# PUDEP        1
# Name: count, Length: 674, dtype: int64

# %% [markdown]
# ### Mapping

# %% [markdown]
# **map() -- applicable on Series**

# %%
mean_votes = ed.total_votes.mean()
ed.total_votes.map(lambda x:x-mean_vote)

# %%
ed.head(2)

# %% [markdown]
# **apply() -- applicable on DataFrame**

# %%
def remean(row):
  row.total_votes = row.total_votes - mean_votes
  return row

ed.apply(remean, axis = "columns")

# %% [markdown]
# ****Neither of them mutates the original data**
